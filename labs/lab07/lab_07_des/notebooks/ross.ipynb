# %% [markdown]
# # Ross model baseline experiment
#
# This file is used only for generation with Literate.jl.
# Run the ordinary script `scripts/ross.jl` for the baseline experiment.

# %%
using DrWatson
@quickactivate "lab_07_des"

include(srcdir("QueueingModels.jl"))
# Out:
# Main.var"##302".QueueingModels

# %% [markdown]
# ## Run

# %%
QueueingModels.run_ross_experiment(;
    N = 10,
    S = 3,
    repairers = 1,
    mean_time_to_failure = 100.0,
    mean_repair_time = 1.0,
    runs = 300,
    seed = 150,
)
# Out:
# Could not create decoration from factory! Running with no decorations.
# Ross model experiment completed.
# Saved data/ross_events_sample.csv
# Saved data/ross_runs.csv
# Saved data/ross_summary.csv
# Saved plots/ross_good_machines.png
# Saved plots/ross_spares.png
# Saved plots/ross_repair_queue.png
# Saved plots/ross_crash_time_histogram.png
# Saved plots/ross_simulation_vs_analytic.png
# Saved plots/ross_repairer_utilization.png
# (sample = (crash_time = 29185.53486290023, events = 9124×8 DataFrame
#   Row │ time         event          working  spares  broken  repair_queue  bus ⋯
#       │ Float64      String         Int64    Int64   Int64   Int64         Int ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │     0.0      start               10       3       0             0      ⋯
#     2 │     1.94719  failure             10       2       0             0
#     3 │     1.94719  repair_start        10       2       1             0
#     4 │     4.39611  repair_finish       10       3       0             0
#     5 │    12.247    failure             10       2       0             0      ⋯
#     6 │    12.247    repair_start        10       2       1             0
#     7 │    14.2728   failure             10       1       1             0
#     8 │    14.2728   repair_queue        10       1       2             1
#   ⋮   │      ⋮             ⋮           ⋮       ⋮       ⋮          ⋮            ⋱
#  9118 │ 29183.2      failure             10       0       2             1      ⋯
#  9119 │ 29183.2      repair_queue        10       0       3             2
#  9120 │ 29184.1      repair_finish       10       1       2             2
#  9121 │ 29184.1      repair_start        10       1       2             1
#  9122 │ 29184.9      failure             10       0       2             1      ⋯
#  9123 │ 29184.9      repair_queue        10       0       3             2
#  9124 │ 29185.5      crash                9       0       3             2
#                                                  2 columns and 9109 rows omitted, metrics = (crash_time = 29185.53486290023, mean_repair_queue = 0.01246007511942771, mean_busy_repairers = 0.10260283011657474, repairer_utilization = 0.10260283011657474)), runs = 300×4 DataFrame
#  Row │ run_id  crash_time  mean_repair_queue  repairer_utilization
#      │ Int64   Float64     Float64            Float64
# ─────┼─────────────────────────────────────────────────────────────
#    1 │      1    1669.89          0.0122765              0.106313
#    2 │      2   42675.7           0.0101453              0.101065
#    3 │      3   18234.5           0.0111972              0.104698
#    4 │      4    2719.42          0.0136136              0.100379
#    5 │      5    3409.05          0.00840118             0.105639
#    6 │      6   20130.3           0.0115073              0.100651
#    7 │      7   18217.8           0.00836339             0.0976503
#    8 │      8    5180.27          0.00876061             0.0949183
#   ⋮  │   ⋮         ⋮               ⋮                   ⋮
#  294 │    294     444.324         0.0453407              0.119636
#  295 │    295    2192.73          0.0112706              0.107137
#  296 │    296   15079.3           0.0109291              0.0988911
#  297 │    297   27945.4           0.0116337              0.103612
#  298 │    298    3247.58          0.0178331              0.111481
#  299 │    299   27447.3           0.0107851              0.0985283
#  300 │    300   21867.9           0.0106466              0.0997579
#                                                    285 rows omitted, summary = 1×9 DataFrame
#  Row │ N      S      repairers  runs   mean_crash_time  std_crash_time  analyt ⋯
#      │ Int64  Int64  Int64      Int64  Float64          Float64         Float6 ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │    10      3          1    300          11996.2         12450.2         ⋯
#                                                                3 columns omitted)
