# %% [markdown]
# # M/M/c baseline experiment
#
# This file is used only for generation with Literate.jl.
# Run the ordinary script `scripts/mmc.jl` for the baseline experiment.

# %%
using DrWatson
@quickactivate "lab_07_des"

include(srcdir("QueueingModels.jl"))
using .QueueingModels

# %% [markdown]
# ## Run

# %%
run_mmc_experiment(;
    lambda = 0.9,
    mu = 0.5,
    c = 2,
    num_customers = 5000,
    seed = 123,
)
# Out:
# Could not create decoration from factory! Running with no decorations.
# M/M/c experiment completed.
# Saved data/mmc_customers.csv
# Saved data/mmc_events.csv
# Saved data/mmc_summary.csv
# Saved plots/mmc_queue_length.png
# Saved plots/mmc_busy_servers.png
# Saved plots/mmc_wait_histogram.png
# Saved plots/mmc_analytic_vs_simulation.png
# (customers = 5000×8 DataFrame
#   Row │ id     arrival_time  service_start  departure_time  wait_time  service ⋯
#       │ Int64  Float64       Float64        Float64         Float64    Float64 ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │     1      0.145185       0.145185        0.953382    0.0         0.80 ⋯
#     2 │     2      1.10007        1.10007         1.23545     0.0         0.13
#     3 │     3      1.16689        1.16689         2.26093     0.0         1.09
#     4 │     4      3.24591        3.24591         4.66254     0.0         1.41
#     5 │     5      5.09096        5.09096         6.56516     0.0         1.47 ⋯
#     6 │     6      6.23308        6.23308        11.5396      0.0         5.30
#     7 │     7      7.00042        7.00042        13.0889      0.0         6.08
#     8 │     8      9.07458       11.5396         19.3073      2.46504     7.76
#   ⋮   │   ⋮         ⋮              ⋮              ⋮             ⋮           ⋮  ⋱
#  4994 │  4994   5485.3         5493.78         5493.8         8.48311     0.01 ⋯
#  4995 │  4995   5485.44        5493.8          5494.37        8.36035     0.57
#  4996 │  4996   5486.01        5494.37         5497.84        8.36652     3.47
#  4997 │  4997   5486.02        5496.31         5497.97       10.2834      1.66
#  4998 │  4998   5486.63        5497.84         5500.07       11.211       2.22 ⋯
#  4999 │  4999   5487.63        5497.97         5498.68       10.3425      0.71
#  5000 │  5000   5487.76        5498.68         5499.51       10.9218      0.82
#                                                  3 columns and 4985 rows omitted, events = 15000×6 DataFrame
#    Row │ time         event          customer_id  queue_length  busy_servers   ⋯
#        │ Float64      String         Int64        Int64         Int64          ⋯
# ───────┼────────────────────────────────────────────────────────────────────────
#      1 │    0.145185  arrival                  1             1             0   ⋯
#      2 │    0.145185  service_start            1             0             1
#      3 │    0.953382  departure                1             0             0
#      4 │    1.10007   arrival                  2             1             0
#      5 │    1.10007   service_start            2             0             1   ⋯
#      6 │    1.16689   arrival                  3             1             1
#      7 │    1.16689   service_start            3             0             2
#      8 │    1.23545   departure                2             0             1
#    ⋮   │      ⋮             ⋮             ⋮            ⋮             ⋮         ⋱
#  14994 │ 5497.84      departure             4996             2             2   ⋯
#  14995 │ 5497.97      service_start         4999             1             3
#  14996 │ 5497.97      departure             4997             1             2
#  14997 │ 5498.68      service_start         5000             0             3
#  14998 │ 5498.68      departure             4999             0             2   ⋯
#  14999 │ 5499.51      departure             5000             0             1
#  15000 │ 5500.07      departure             4998             0             0
#                                                  1 column and 14985 rows omitted, summary = 1×17 DataFrame
#  Row │ lambda   mu       c      num_customers  seed   rho      analytic_wq  si ⋯
#      │ Float64  Float64  Int64  Int64          Int64  Float64  Float64      Fl ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │     0.9      0.5      2           5000    123      0.9      8.52632  8. ⋯
#                                                               10 columns omitted)
